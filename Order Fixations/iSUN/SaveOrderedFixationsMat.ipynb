# %%
import numpy as np
import scipy.io
import matplotlib.image as mpimg
import isunapi as api
import time
import sys
import generate_meanshift_fix

# %%
#Load training data
iSUN_PATH='../../Datasets/iSUN/'
MAT_TRAIN_SUN = iSUN_PATH + 'training.mat'
train = scipy.io.loadmat(MAT_TRAIN_SUN)

# %%
generate_meanshift_fix.save_training_ms_fixations(train)
# Out:
# Fixations of image 0 done!
# Fixations of image 1 done!
# Fixations of image 2 done!
# Fixations of image 3 done!
# Fixations of image 4 done!
# Fixations of image 5 done!
# Fixations of image 6 done!
# Fixations of image 7 done!
# Fixations of image 8 done!
# Fixations of image 9 done!
# Fixations of image 10 done!
# Fixations of image 11 done!
# Fixations of image 12 done!
# Fixations of image 13 done!
# Fixations of image 14 done!
# Fixations of image 15 done!
# Fixations of image 16 done!
# Fixations of image 17 done!
# Fixations of image 18 done!
# Fixations of image 19 done!
# Fixations of image 20 done!
# Fixations of image 21 done!
# Fixations of image 22 done!
# Fixations of image 23 done!
# Fixations of image 24 done!
# Fixations of image 25 done!
# Fixations of image 26 done!
# Fixations of image 27 done!
# Fixations of image 28 done!
# Fixations of image 29 done!
# Fixations of image 30 done!
# Fixations of image 31 done!
# Fixations of image 32 done!
# Fixations of image 33 done!
# Fixations of image 34 done!
# Fixations of image 35 done!
# Fixations of image 36 done!
# Fixations of image 37 done!
# Fixations of image 38 done!
# Fixations of image 39 done!
# Fixations of image 40 done!
# Fixations of image 41 done!
# Fixations of image 42 done!
# Fixations of image 43 done!
# Fixations of image 44 done!
# Fixations of image 45 done!
# Fixations of image 46 done!
# Fixations of image 47 done!
# Fixations of image 48 done!
# Fixations of image 49 done!
# Fixations of image 50 done!
# Fixations of image 51 done!
# Fixations of image 52 done!
# Fixations of image 53 done!
# Fixations of image 54 done!
# Fixations of image 55 done!
# Fixations of image 56 done!
# Fixations of image 57 done!
# Fixations of image 58 done!
# Fixations of image 59 done!
# Fixations of image 60 done!
# Fixations of image 61 done!
# Fixations of image 62 done!
# Fixations of image 63 done!
# Fixations of image 64 done!
# Fixations of image 65 done!
# Fixations of image 66 done!
# Fixations of image 67 done!
# Fixations of image 68 done!
# Fixations of image 69 done!
# Fixations of image 70 done!
# Fixations of image 71 done!
# Fixations of image 72 done!
# Fixations of image 73 done!
# Fixations of image 74 done!
# Fixations of image 75 done!
# Fixations of image 76 done!
# Fixations of image 77 done!
# Fixations of image 78 done!
# Fixations of image 79 done!
# Fixations of image 80 done!
# Fixations of image 81 done!
# Fixations of image 82 done!
# Fixations of image 83 done!
# Fixations of image 84 done!
# Fixations of image 85 done!
# Fixations of image 86 done!
# Fixations of image 87 done!
# Fixations of image 88 done!
# Fixations of image 89 done!
# Fixations of image 90 done!
# Fixations of image 91 done!
# Fixations of image 92 done!
# Fixations of image 93 done!
# Fixations of image 94 done!
# Fixations of image 95 done!
# Fixations of image 96 done!
# Fixations of image 97 done!
# Fixations of image 98 done!
# Fixations of image 99 done!
# Fixations of image 100 done!
# Fixations of image 101 done!
# Fixations of image 102 done!
# Fixations of image 103 done!
# Fixations of image 104 done!
# Fixations of image 105 done!
# Fixations of image 106 done!
# Fixations of image 107 done!
# Fixations of image 108 done!
# Fixations of image 109 done!
# Fixations of image 110 done!
# Fixations of image 111 done!
# Fixations of image 112 done!
# Fixations of image 113 done!
# Fixations of image 114 done!
# Fixations of image 115 done!
# Fixations of image 116 done!
# Fixations of image 117 done!
# Fixations of image 118 done!
# Fixations of image 119 done!
# Fixations of image 120 done!
# Fixations of image 121 done!
# Fixations of image 122 done!
# Fixations of image 123 done!
# Fixations of image 124 done!
# Fixations of image 125 done!
# Fixations of image 126 done!
# Fixations of image 127 done!
# Fixations of image 128 done!
# Fixations of image 129 done!
# Fixations of image 130 done!
# Fixations of image 131 done!
# Fixations of image 132 done!
# Fixations of image 133 done!
# Fixations of image 134 done!
# Fixations of image 135 done!
# Fixations of image 136 done!
# Fixations of image 137 done!
# Fixations of image 138 done!
# Fixations of image 139 done!
# Fixations of image 140 done!
# Fixations of image 141 done!
# Fixations of image 142 done!
# Fixations of image 143 done!
# Fixations of image 144 done!
# Fixations of image 145 done!
# Fixations of image 146 done!
# Fixations of image 147 done!
# Fixations of image 148 done!
# Fixations of image 149 done!
# Fixations of image 150 done!
# Fixations of image 151 done!
# Fixations of image 152 done!
# Fixations of image 153 done!
# Fixations of image 154 done!
# Fixations of image 155 done!
# Fixations of image 156 done!
# Fixations of image 157 done!
# Fixations of image 158 done!
# Fixations of image 159 done!
# Fixations of image 160 done!
# Fixations of image 161 done!
# Fixations of image 162 done!
# Fixations of image 163 done!
# Fixations of image 164 done!
# Fixations of image 165 done!
# Fixations of image 166 done!
# Fixations of image 167 done!
# Fixations of image 168 done!
# Fixations of image 169 done!
# Fixations of image 170 done!
# Fixations of image 171 done!
# Fixations of image 172 done!
# Fixations of image 173 done!
# Fixations of image 174 done!
# Fixations of image 175 done!
# Fixations of image 176 done!
# Fixations of image 177 done!
# Fixations of image 178 done!
# Fixations of image 179 done!
# Fixations of image 180 done!
# Fixations of image 181 done!
# Fixations of image 182 done!
# Fixations of image 183 done!
# Fixations of image 184 done!
# Fixations of image 185 done!
# Fixations of image 186 done!
# Fixations of image 187 done!
# Fixations of image 188 done!
# Fixations of image 189 done!
# Fixations of image 190 done!
# Fixations of image 191 done!
# Fixations of image 192 done!
# Fixations of image 193 done!
# Fixations of image 194 done!
# Fixations of image 195 done!
# Fixations of image 196 done!
# Fixations of image 197 done!
# Fixations of image 198 done!
# Fixations of image 199 done!
# Fixations of image 200 done!
# Fixations of image 201 done!
# Fixations of image 202 done!
# Fixations of image 203 done!
# Fixations of image 204 done!
# Fixations of image 205 done!
# Fixations of image 206 done!
# Fixations of image 207 done!
# Fixations of image 208 done!
# Fixations of image 209 done!
# Fixations of image 210 done!
# Fixations of image 211 done!
# Fixations of image 212 done!
# Fixations of image 213 done!
# Fixations of image 214 done!
# Fixations of image 215 done!
# Fixations of image 216 done!
# Fixations of image 217 done!
# Fixations of image 218 done!
# Fixations of image 219 done!
# Fixations of image 220 done!
# Fixations of image 221 done!
# Fixations of image 222 done!
# Fixations of image 223 done!
# Fixations of image 224 done!
# Fixations of image 225 done!
# Fixations of image 226 done!
# Fixations of image 227 done!
# Fixations of image 228 done!
# Fixations of image 229 done!
# Fixations of image 230 done!
# Fixations of image 231 done!
# Fixations of image 232 done!
# Fixations of image 233 done!
# Fixations of image 234 done!
# Fixations of image 235 done!
# Fixations of image 236 done!
# Fixations of image 237 done!
# Fixations of image 238 done!
# Fixations of image 239 done!
# Fixations of image 240 done!
# Fixations of image 241 done!
# Fixations of image 242 done!
# Fixations of image 243 done!
# Fixations of image 244 done!
# Fixations of image 245 done!
# Fixations of image 246 done!
# Fixations of image 247 done!
# Fixations of image 248 done!
# Fixations of image 249 done!
# Fixations of image 250 done!
# Fixations of image 251 done!
# Fixations of image 252 done!
# Fixations of image 253 done!
# Fixations of image 254 done!
# Fixations of image 255 done!
# Fixations of image 256 done!
# Fixations of image 257 done!
# Fixations of image 258 done!
# Fixations of image 259 done!
# Fixations of image 260 done!
# Fixations of image 261 done!
# Fixations of image 262 done!
# Fixations of image 263 done!
# Fixations of image 264 done!
# Fixations of image 265 done!
# Fixations of image 266 done!
# Fixations of image 267 done!
# Fixations of image 268 done!
# Fixations of image 269 done!
# Fixations of image 270 done!
# Fixations of image 271 done!
# Fixations of image 272 done!
# Fixations of image 273 done!
# Fixations of image 274 done!
# Fixations of image 275 done!
# Fixations of image 276 done!
# Fixations of image 277 done!
# Fixations of image 278 done!
# Fixations of image 279 done!
# Fixations of image 280 done!
# Fixations of image 281 done!
# Fixations of image 282 done!
# Fixations of image 283 done!
# Fixations of image 284 done!
# Fixations of image 285 done!
# Fixations of image 286 done!
# Fixations of image 287 done!
# Fixations of image 288 done!
# Fixations of image 289 done!
# Fixations of image 290 done!
# Fixations of image 291 done!
# Fixations of image 292 done!
# Fixations of image 293 done!
# Fixations of image 294 done!
# Fixations of image 295 done!
# Fixations of image 296 done!
# Fixations of image 297 done!
# Fixations of image 298 done!
# Fixations of image 299 done!
# Fixations of image 300 done!
# Fixations of image 301 done!
# Fixations of image 302 done!
# Fixations of image 303 done!
# Fixations of image 304 done!
# Fixations of image 305 done!
# Fixations of image 306 done!
# Fixations of image 307 done!
# Fixations of image 308 done!
# Fixations of image 309 done!
# Fixations of image 310 done!
# Fixations of image 311 done!
# Fixations of image 312 done!
# Fixations of image 313 done!
# Fixations of image 314 done!
# Fixations of image 315 done!
# Fixations of image 316 done!
# Fixations of image 317 done!
# Fixations of image 318 done!
# Fixations of image 319 done!
# Fixations of image 320 done!
# Fixations of image 321 done!
# Fixations of image 322 done!
# Fixations of image 323 done!
# Fixations of image 324 done!
# Fixations of image 325 done!
# Fixations of image 326 done!
# Fixations of image 327 done!
# Fixations of image 328 done!
# Fixations of image 329 done!
# Fixations of image 330 done!
# Fixations of image 331 done!
# Fixations of image 332 done!
# Fixations of image 333 done!
# Fixations of image 334 done!
# Fixations of image 335 done!
# Fixations of image 336 done!
# Fixations of image 337 done!
# Fixations of image 338 done!
# Fixations of image 339 done!
# Fixations of image 340 done!
# Fixations of image 341 done!
# Fixations of image 342 done!
# Fixations of image 343 done!
# Fixations of image 344 done!
# Fixations of image 345 done!
# Fixations of image 346 done!
# Fixations of image 347 done!
# Fixations of image 348 done!
# Fixations of image 349 done!
# Fixations of image 350 done!
# Fixations of image 351 done!
# Fixations of image 352 done!
# Fixations of image 353 done!
# Fixations of image 354 done!
# Fixations of image 355 done!
# Fixations of image 356 done!
# Fixations of image 357 done!
# Fixations of image 358 done!
# Fixations of image 359 done!
# Fixations of image 360 done!
# Fixations of image 361 done!
# Fixations of image 362 done!
# Fixations of image 363 done!
# Fixations of image 364 done!
# Fixations of image 365 done!
# Fixations of image 366 done!
# Fixations of image 367 done!
# Fixations of image 368 done!
# Fixations of image 369 done!
# Fixations of image 370 done!
# Fixations of image 371 done!
# Fixations of image 372 done!
# Fixations of image 373 done!
# Fixations of image 374 done!
# Fixations of image 375 done!
# Fixations of image 376 done!
# Fixations of image 377 done!
# Fixations of image 378 done!
# Fixations of image 379 done!
# Fixations of image 380 done!
# Fixations of image 381 done!
# Fixations of image 382 done!
# Fixations of image 383 done!
# Fixations of image 384 done!
# Fixations of image 385 done!
# Fixations of image 386 done!
# Fixations of image 387 done!
# Fixations of image 388 done!
# Fixations of image 389 done!
# Fixations of image 390 done!
# Fixations of image 391 done!
# Fixations of image 392 done!
# Fixations of image 393 done!
# Fixations of image 394 done!
# Fixations of image 395 done!
# Fixations of image 396 done!
# Fixations of image 397 done!
# Fixations of image 398 done!
# Fixations of image 399 done!
# Fixations of image 400 done!
# Fixations of image 401 done!
# Fixations of image 402 done!
# Fixations of image 403 done!
# Fixations of image 404 done!
# Fixations of image 405 done!
# Fixations of image 406 done!
# Fixations of image 407 done!
# Fixations of image 408 done!
# Fixations of image 409 done!
# Fixations of image 410 done!
# Fixations of image 411 done!
# Fixations of image 412 done!
# Fixations of image 413 done!
# Fixations of image 414 done!
# Fixations of image 415 done!
# Fixations of image 416 done!
# Fixations of image 417 done!
# Fixations of image 418 done!
# Fixations of image 419 done!
# Fixations of image 420 done!
# Fixations of image 421 done!
# Fixations of image 422 done!
# Fixations of image 423 done!
# Fixations of image 424 done!
# Fixations of image 425 done!
# Fixations of image 426 done!
# Fixations of image 427 done!
# Fixations of image 428 done!
# Fixations of image 429 done!
# Fixations of image 430 done!
# Fixations of image 431 done!
# Fixations of image 432 done!
# Fixations of image 433 done!
# Fixations of image 434 done!
# Fixations of image 435 done!
# Fixations of image 436 done!
# Fixations of image 437 done!
# Fixations of image 438 done!
# Fixations of image 439 done!
# Fixations of image 440 done!
# Fixations of image 441 done!
# Fixations of image 442 done!
# Fixations of image 443 done!
# Fixations of image 444 done!
# Fixations of image 445 done!
# Fixations of image 446 done!
# Fixations of image 447 done!
# Fixations of image 448 done!
# Fixations of image 449 done!
# Fixations of image 450 done!
# Fixations of image 451 done!
# Fixations of image 452 done!
# Fixations of image 453 done!
# Fixations of image 454 done!
# Fixations of image 455 done!
# Fixations of image 456 done!
# Fixations of image 457 done!
# Fixations of image 458 done!
# Fixations of image 459 done!
# Fixations of image 460 done!
# Fixations of image 461 done!
# Fixations of image 462 done!
# Fixations of image 463 done!
# Fixations of image 464 done!
# Fixations of image 465 done!
# Fixations of image 466 done!
# Fixations of image 467 done!
# Fixations of image 468 done!
# Fixations of image 469 done!
# Fixations of image 470 done!
# Fixations of image 471 done!
# Fixations of image 472 done!
# Fixations of image 473 done!
# Fixations of image 474 done!
# Fixations of image 475 done!
# Fixations of image 476 done!
# Fixations of image 477 done!
# Fixations of image 478 done!
# Fixations of image 479 done!
# Fixations of image 480 done!
# Fixations of image 481 done!
# Fixations of image 482 done!
# Fixations of image 483 done!
# Fixations of image 484 done!
# Fixations of image 485 done!
# Fixations of image 486 done!
# Fixations of image 487 done!
# Fixations of image 488 done!
# Fixations of image 489 done!
# Fixations of image 490 done!
# Fixations of image 491 done!
# Fixations of image 492 done!
# Fixations of image 493 done!
# Fixations of image 494 done!
# Fixations of image 495 done!
# Fixations of image 496 done!
# Fixations of image 497 done!
# Fixations of image 498 done!
# Fixations of image 499 done!
# Fixations of image 500 done!
# Fixations of image 501 done!
# Fixations of image 502 done!
# Fixations of image 503 done!
# Fixations of image 504 done!
# Fixations of image 505 done!
# Fixations of image 506 done!
# Fixations of image 507 done!
# Fixations of image 508 done!
# Fixations of image 509 done!
# Fixations of image 510 done!
# Fixations of image 511 done!
# Fixations of image 512 done!
# Fixations of image 513 done!
# Fixations of image 514 done!
# Fixations of image 515 done!
# Fixations of image 516 done!
# Fixations of image 517 done!
# Fixations of image 518 done!
# Fixations of image 519 done!
# Fixations of image 520 done!
# Fixations of image 521 done!
# Fixations of image 522 done!
# Fixations of image 523 done!
# Fixations of image 524 done!
# Fixations of image 525 done!
# Fixations of image 526 done!
# Fixations of image 527 done!
# Fixations of image 528 done!
# Fixations of image 529 done!
# Fixations of image 530 done!
# Fixations of image 531 done!
# Fixations of image 532 done!
# Fixations of image 533 done!
# Fixations of image 534 done!
# Fixations of image 535 done!
# Fixations of image 536 done!
# Fixations of image 537 done!
# Fixations of image 538 done!
# Fixations of image 539 done!
# Fixations of image 540 done!
# Fixations of image 541 done!
# Fixations of image 542 done!
# Fixations of image 543 done!
# Fixations of image 544 done!
# Fixations of image 545 done!
# Fixations of image 546 done!
# Fixations of image 547 done!
# Fixations of image 548 done!
# Fixations of image 549 done!
# Fixations of image 550 done!
# Fixations of image 551 done!
# Fixations of image 552 done!
# Fixations of image 553 done!
# Fixations of image 554 done!
# Fixations of image 555 done!
# Fixations of image 556 done!
# Fixations of image 557 done!
# Fixations of image 558 done!
# Fixations of image 559 done!
# Fixations of image 560 done!
# Fixations of image 561 done!
# Fixations of image 562 done!
# Fixations of image 563 done!
# Fixations of image 564 done!
# Fixations of image 565 done!
# Fixations of image 566 done!
# Fixations of image 567 done!
# Fixations of image 568 done!
# Fixations of image 569 done!
# Fixations of image 570 done!
# Fixations of image 571 done!
# Fixations of image 572 done!
# Fixations of image 573 done!
# Fixations of image 574 done!
# Fixations of image 575 done!
# Fixations of image 576 done!
# Fixations of image 577 done!
# Fixations of image 578 done!
# Fixations of image 579 done!
# Fixations of image 580 done!
# Fixations of image 581 done!
# Fixations of image 582 done!
# Fixations of image 583 done!
# Fixations of image 584 done!
# Fixations of image 585 done!
# Fixations of image 586 done!
# Fixations of image 587 done!
# Fixations of image 588 done!
# Fixations of image 589 done!
# Fixations of image 590 done!
# Fixations of image 591 done!
# Fixations of image 592 done!
# Fixations of image 593 done!
# Fixations of image 594 done!
# Fixations of image 595 done!
# Fixations of image 596 done!
# Fixations of image 597 done!
# Fixations of image 598 done!
# Fixations of image 599 done!
# Fixations of image 600 done!
# Fixations of image 601 done!
# Fixations of image 602 done!
# Fixations of image 603 done!
# Fixations of image 604 done!
# Fixations of image 605 done!
# Fixations of image 606 done!
# Fixations of image 607 done!
# Fixations of image 608 done!
# Fixations of image 609 done!
# Fixations of image 610 done!
# Fixations of image 611 done!
# Fixations of image 612 done!
# Fixations of image 613 done!
# Fixations of image 614 done!
# Fixations of image 615 done!
# Fixations of image 616 done!
# Fixations of image 617 done!
# Fixations of image 618 done!
# Fixations of image 619 done!
# Fixations of image 620 done!
# Fixations of image 621 done!
# Fixations of image 622 done!
# Fixations of image 623 done!
# Fixations of image 624 done!
# Fixations of image 625 done!
# Fixations of image 626 done!
# Fixations of image 627 done!
# Fixations of image 628 done!
# Fixations of image 629 done!
# Fixations of image 630 done!
# Fixations of image 631 done!
# Fixations of image 632 done!
# Fixations of image 633 done!
# Fixations of image 634 done!
# Fixations of image 635 done!
# Fixations of image 636 done!
# Fixations of image 637 done!
# Fixations of image 638 done!
# Fixations of image 639 done!
# Fixations of image 640 done!
# Fixations of image 641 done!
# Fixations of image 642 done!
# Fixations of image 643 done!
# Fixations of image 644 done!
# Fixations of image 645 done!
# Fixations of image 646 done!
# Fixations of image 647 done!
# Fixations of image 648 done!
# Fixations of image 649 done!
# Fixations of image 650 done!
# Fixations of image 651 done!
# Fixations of image 652 done!
# Fixations of image 653 done!
# Fixations of image 654 done!
# Fixations of image 655 done!
# Fixations of image 656 done!
# Fixations of image 657 done!
# Fixations of image 658 done!
# Fixations of image 659 done!
# Fixations of image 660 done!
# Fixations of image 661 done!
# Fixations of image 662 done!
# Fixations of image 663 done!
# Fixations of image 664 done!
# Fixations of image 665 done!
# Fixations of image 666 done!
# Fixations of image 667 done!
# Fixations of image 668 done!
# Fixations of image 669 done!
# Fixations of image 670 done!
# Fixations of image 671 done!
# Fixations of image 672 done!
# Fixations of image 673 done!
# Fixations of image 674 done!
# Fixations of image 675 done!
# Fixations of image 676 done!
# Fixations of image 677 done!
# Fixations of image 678 done!
# Fixations of image 679 done!
# Fixations of image 680 done!
# Fixations of image 681 done!
# Fixations of image 682 done!
# Fixations of image 683 done!
# Fixations of image 684 done!
# Fixations of image 685 done!
# Fixations of image 686 done!
# Fixations of image 687 done!
# Fixations of image 688 done!
# Fixations of image 689 done!
# Fixations of image 690 done!
# Fixations of image 691 done!
# Fixations of image 692 done!
# Fixations of image 693 done!
# Fixations of image 694 done!
# Fixations of image 695 done!
# Fixations of image 696 done!
# Fixations of image 697 done!
# Fixations of image 698 done!
# Fixations of image 699 done!
# Fixations of image 700 done!
# Fixations of image 701 done!
# Fixations of image 702 done!
# Fixations of image 703 done!
# Fixations of image 704 done!
# Fixations of image 705 done!
# Fixations of image 706 done!
# Fixations of image 707 done!
# Fixations of image 708 done!
# Fixations of image 709 done!
# Fixations of image 710 done!
# Fixations of image 711 done!
# Fixations of image 712 done!
# Fixations of image 713 done!
# Fixations of image 714 done!
# Fixations of image 715 done!
# Fixations of image 716 done!
# Fixations of image 717 done!
# Fixations of image 718 done!
# Fixations of image 719 done!
# Fixations of image 720 done!
# Fixations of image 721 done!
# Fixations of image 722 done!
# Fixations of image 723 done!
# Fixations of image 724 done!
# Fixations of image 725 done!
# Fixations of image 726 done!
# Fixations of image 727 done!
# Fixations of image 728 done!
# Fixations of image 729 done!
# Fixations of image 730 done!
# Fixations of image 731 done!
# Fixations of image 732 done!
# Fixations of image 733 done!
# Fixations of image 734 done!
# Fixations of image 735 done!
# Fixations of image 736 done!
# Fixations of image 737 done!
# Fixations of image 738 done!
# Fixations of image 739 done!
# Fixations of image 740 done!
# Fixations of image 741 done!
# Fixations of image 742 done!
# Fixations of image 743 done!
# Fixations of image 744 done!
# Fixations of image 745 done!
# Fixations of image 746 done!
# Fixations of image 747 done!
# Fixations of image 748 done!
# Fixations of image 749 done!
# Fixations of image 750 done!
# Fixations of image 751 done!
# Fixations of image 752 done!
# Fixations of image 753 done!
# Fixations of image 754 done!
# Fixations of image 755 done!
# Fixations of image 756 done!
# Fixations of image 757 done!
# Fixations of image 758 done!
# Fixations of image 759 done!
# Fixations of image 760 done!
# Fixations of image 761 done!
# Fixations of image 762 done!
# Fixations of image 763 done!
# Fixations of image 764 done!
# Fixations of image 765 done!
# Fixations of image 766 done!
# Fixations of image 767 done!
# Fixations of image 768 done!
# Fixations of image 769 done!
# Fixations of image 770 done!
# Fixations of image 771 done!
# Fixations of image 772 done!
# Fixations of image 773 done!
# Fixations of image 774 done!
# Fixations of image 775 done!
# Fixations of image 776 done!
# Fixations of image 777 done!
# Fixations of image 778 done!
# Fixations of image 779 done!
# Fixations of image 780 done!
# Fixations of image 781 done!
# Fixations of image 782 done!
# Fixations of image 783 done!
# Fixations of image 784 done!
# Fixations of image 785 done!
# Fixations of image 786 done!
# Fixations of image 787 done!
# Fixations of image 788 done!
# Fixations of image 789 done!
# Fixations of image 790 done!
# Fixations of image 791 done!
# Fixations of image 792 done!
# Fixations of image 793 done!
# Fixations of image 794 done!
# Fixations of image 795 done!
# Fixations of image 796 done!
# Fixations of image 797 done!
# Fixations of image 798 done!
# Fixations of image 799 done!
# Fixations of image 800 done!
# Fixations of image 801 done!
# Fixations of image 802 done!
# Fixations of image 803 done!
# Fixations of image 804 done!
# Fixations of image 805 done!
# Fixations of image 806 done!
# Fixations of image 807 done!
# Fixations of image 808 done!
# Fixations of image 809 done!
# Fixations of image 810 done!
# Fixations of image 811 done!
# Fixations of image 812 done!
# Fixations of image 813 done!
# Fixations of image 814 done!
# Fixations of image 815 done!
# Fixations of image 816 done!
# Fixations of image 817 done!
# Fixations of image 818 done!
# Fixations of image 819 done!
# Fixations of image 820 done!
# Fixations of image 821 done!
# Fixations of image 822 done!
# Fixations of image 823 done!
# Fixations of image 824 done!
# Fixations of image 825 done!
# Fixations of image 826 done!
# Fixations of image 827 done!
# Fixations of image 828 done!
# Fixations of image 829 done!
# Fixations of image 830 done!
# Fixations of image 831 done!
# Fixations of image 832 done!
# Fixations of image 833 done!
# Fixations of image 834 done!
# Fixations of image 835 done!
# Fixations of image 836 done!
# Fixations of image 837 done!
# Fixations of image 838 done!
# Fixations of image 839 done!
# Fixations of image 840 done!
# Fixations of image 841 done!
# Fixations of image 842 done!
# Fixations of image 843 done!
# Fixations of image 844 done!
# Fixations of image 845 done!
# Fixations of image 846 done!
# Fixations of image 847 done!
# Fixations of image 848 done!
# Fixations of image 849 done!
# Fixations of image 850 done!
# Fixations of image 851 done!
# Fixations of image 852 done!
# Fixations of image 853 done!
# Fixations of image 854 done!
# Fixations of image 855 done!
# Fixations of image 856 done!
# Fixations of image 857 done!
# Fixations of image 858 done!
# Fixations of image 859 done!
# Fixations of image 860 done!
# Fixations of image 861 done!
# Fixations of image 862 done!
# Fixations of image 863 done!
# Fixations of image 864 done!
# Fixations of image 865 done!
# Fixations of image 866 done!
# Fixations of image 867 done!
# Fixations of image 868 done!
# Fixations of image 869 done!
# Fixations of image 870 done!
# Fixations of image 871 done!
# Fixations of image 872 done!
# Fixations of image 873 done!
# Fixations of image 874 done!
# Fixations of image 875 done!
# Fixations of image 876 done!
# Fixations of image 877 done!
# Fixations of image 878 done!
# Fixations of image 879 done!
# Fixations of image 880 done!
# Fixations of image 881 done!
# Fixations of image 882 done!
# Fixations of image 883 done!
# Fixations of image 884 done!
# Fixations of image 885 done!
# Fixations of image 886 done!
# Fixations of image 887 done!
# Fixations of image 888 done!
# Fixations of image 889 done!
# Fixations of image 890 done!
# Fixations of image 891 done!
# Fixations of image 892 done!
# Fixations of image 893 done!
# Fixations of image 894 done!
# Fixations of image 895 done!
# Fixations of image 896 done!
# Fixations of image 897 done!
# Fixations of image 898 done!
# Fixations of image 899 done!
# Fixations of image 900 done!
# Fixations of image 901 done!
# Fixations of image 902 done!
# Fixations of image 903 done!
# Fixations of image 904 done!
# Fixations of image 905 done!
# Fixations of image 906 done!
# Fixations of image 907 done!
# Fixations of image 908 done!
# Fixations of image 909 done!
# Fixations of image 910 done!
# Fixations of image 911 done!
# Fixations of image 912 done!
# Fixations of image 913 done!
# Fixations of image 914 done!
# Fixations of image 915 done!
# Fixations of image 916 done!
# Fixations of image 917 done!
# Fixations of image 918 done!
# Fixations of image 919 done!
# Fixations of image 920 done!
# Fixations of image 921 done!
# Fixations of image 922 done!
# Fixations of image 923 done!
# Fixations of image 924 done!
# Fixations of image 925 done!
# Fixations of image 926 done!
# Fixations of image 927 done!
# Fixations of image 928 done!
# Fixations of image 929 done!
# Fixations of image 930 done!
# Fixations of image 931 done!
# Fixations of image 932 done!
# Fixations of image 933 done!
# Fixations of image 934 done!
# Fixations of image 935 done!
# Fixations of image 936 done!
# Fixations of image 937 done!
# Fixations of image 938 done!
# Fixations of image 939 done!
# Fixations of image 940 done!
# Fixations of image 941 done!
# Fixations of image 942 done!
# Fixations of image 943 done!
# Fixations of image 944 done!
# Fixations of image 945 done!
# Fixations of image 946 done!
# Fixations of image 947 done!
# Fixations of image 948 done!
# Fixations of image 949 done!
# Fixations of image 950 done!
# Fixations of image 951 done!
# Fixations of image 952 done!
# Fixations of image 953 done!
# Fixations of image 954 done!
# Fixations of image 955 done!
# Fixations of image 956 done!
# Fixations of image 957 done!
# Fixations of image 958 done!
# Fixations of image 959 done!
# Fixations of image 960 done!
# Fixations of image 961 done!
# Fixations of image 962 done!
# Fixations of image 963 done!
# Fixations of image 964 done!
# Fixations of image 965 done!
# Fixations of image 966 done!
# Fixations of image 967 done!
# Fixations of image 968 done!
# Fixations of image 969 done!
# Fixations of image 970 done!
# Fixations of image 971 done!
# Fixations of image 972 done!
# Fixations of image 973 done!
# Fixations of image 974 done!
# Fixations of image 975 done!
# Fixations of image 976 done!
# Fixations of image 977 done!
# Fixations of image 978 done!
# Fixations of image 979 done!
# Fixations of image 980 done!
# Fixations of image 981 done!
# Fixations of image 982 done!
# Fixations of image 983 done!
# Fixations of image 984 done!
# Fixations of image 985 done!
# Fixations of image 986 done!
# Fixations of image 987 done!
# Fixations of image 988 done!
# Fixations of image 989 done!
# Fixations of image 990 done!
# Fixations of image 991 done!
# Fixations of image 992 done!
# Fixations of image 993 done!
# Fixations of image 994 done!
# Fixations of image 995 done!
# Fixations of image 996 done!
# Fixations of image 997 done!
# Fixations of image 998 done!
# Fixations of image 999 done!
# Fixations of image 1000 done!
# Fixations of image 1001 done!
# Fixations of image 1002 done!
# Fixations of image 1003 done!
# Fixations of image 1004 done!
# Fixations of image 1005 done!
# Fixations of image 1006 done!
# Fixations of image 1007 done!
# Fixations of image 1008 done!
# Fixations of image 1009 done!
# Fixations of image 1010 done!
# Fixations of image 1011 done!
# Fixations of image 1012 done!
# Fixations of image 1013 done!
# Fixations of image 1014 done!
# Fixations of image 1015 done!
# Fixations of image 1016 done!
# Fixations of image 1017 done!
# Fixations of image 1018 done!
# Fixations of image 1019 done!
# Fixations of image 1020 done!
# Fixations of image 1021 done!
# Fixations of image 1022 done!
# Fixations of image 1023 done!
# Fixations of image 1024 done!
# Fixations of image 1025 done!
# Fixations of image 1026 done!
# Fixations of image 1027 done!
# Fixations of image 1028 done!
# Fixations of image 1029 done!
# Fixations of image 1030 done!
# Fixations of image 1031 done!
# Fixations of image 1032 done!
# Fixations of image 1033 done!
# Fixations of image 1034 done!
# Fixations of image 1035 done!
# Fixations of image 1036 done!
# Fixations of image 1037 done!
# Fixations of image 1038 done!
# Fixations of image 1039 done!
# Fixations of image 1040 done!
# Fixations of image 1041 done!
# Fixations of image 1042 done!
# Fixations of image 1043 done!
# Fixations of image 1044 done!
# Fixations of image 1045 done!
# Fixations of image 1046 done!
# Fixations of image 1047 done!
# Fixations of image 1048 done!
# Fixations of image 1049 done!
# Fixations of image 1050 done!
# Fixations of image 1051 done!
# Fixations of image 1052 done!
# Fixations of image 1053 done!
# Fixations of image 1054 done!
# Fixations of image 1055 done!
# Fixations of image 1056 done!
# Fixations of image 1057 done!
# Fixations of image 1058 done!
# Fixations of image 1059 done!
# Fixations of image 1060 done!
# Fixations of image 1061 done!
# Fixations of image 1062 done!
# Fixations of image 1063 done!
# Fixations of image 1064 done!
# Fixations of image 1065 done!
# Fixations of image 1066 done!
# Fixations of image 1067 done!
# Fixations of image 1068 done!
# Fixations of image 1069 done!
# Fixations of image 1070 done!
# Fixations of image 1071 done!
# Fixations of image 1072 done!
# Fixations of image 1073 done!
# Fixations of image 1074 done!
# Fixations of image 1075 done!
# Fixations of image 1076 done!
# Fixations of image 1077 done!
# Fixations of image 1078 done!
# Fixations of image 1079 done!
# Fixations of image 1080 done!
# Fixations of image 1081 done!
# Fixations of image 1082 done!
# Fixations of image 1083 done!
# Fixations of image 1084 done!
# Fixations of image 1085 done!
# Fixations of image 1086 done!
# Fixations of image 1087 done!
# Fixations of image 1088 done!
# Fixations of image 1089 done!
# Fixations of image 1090 done!
# Fixations of image 1091 done!
# Fixations of image 1092 done!
# Fixations of image 1093 done!
# Fixations of image 1094 done!
# Fixations of image 1095 done!
# Fixations of image 1096 done!
# Fixations of image 1097 done!
# Fixations of image 1098 done!
# Fixations of image 1099 done!
# Fixations of image 1100 done!
# Fixations of image 1101 done!
# Fixations of image 1102 done!
# Fixations of image 1103 done!
# Fixations of image 1104 done!
# Fixations of image 1105 done!
# Fixations of image 1106 done!
# Fixations of image 1107 done!
# Fixations of image 1108 done!
# Fixations of image 1109 done!
# Fixations of image 1110 done!
# Fixations of image 1111 done!
# Fixations of image 1112 done!
# Fixations of image 1113 done!
# Fixations of image 1114 done!
# Fixations of image 1115 done!
# Fixations of image 1116 done!
# Fixations of image 1117 done!
# Fixations of image 1118 done!
# Fixations of image 1119 done!
# Fixations of image 1120 done!
# Fixations of image 1121 done!
# Fixations of image 1122 done!
# Fixations of image 1123 done!
# Fixations of image 1124 done!
# Fixations of image 1125 done!
# Fixations of image 1126 done!
# Fixations of image 1127 done!
# Fixations of image 1128 done!
# Fixations of image 1129 done!
# Fixations of image 1130 done!
# Fixations of image 1131 done!
# Fixations of image 1132 done!
# Fixations of image 1133 done!
# Fixations of image 1134 done!
# Fixations of image 1135 done!
# Fixations of image 1136 done!
# Fixations of image 1137 done!
# Fixations of image 1138 done!
# Fixations of image 1139 done!
# Fixations of image 1140 done!
# Fixations of image 1141 done!
# Fixations of image 1142 done!
# Fixations of image 1143 done!
# Fixations of image 1144 done!
# Fixations of image 1145 done!
# Fixations of image 1146 done!
# Fixations of image 1147 done!
# Fixations of image 1148 done!
# Fixations of image 1149 done!
# Fixations of image 1150 done!
# Fixations of image 1151 done!
# Fixations of image 1152 done!
# Fixations of image 1153 done!
# Fixations of image 1154 done!
# Fixations of image 1155 done!
# Fixations of image 1156 done!
# Fixations of image 1157 done!
# Fixations of image 1158 done!
# Fixations of image 1159 done!
# Fixations of image 1160 done!
# Fixations of image 1161 done!
# Fixations of image 1162 done!
# Fixations of image 1163 done!
# Fixations of image 1164 done!
# Fixations of image 1165 done!
# Fixations of image 1166 done!
# Fixations of image 1167 done!
# Fixations of image 1168 done!
# Fixations of image 1169 done!
# Fixations of image 1170 done!
# Fixations of image 1171 done!
# Fixations of image 1172 done!
# Fixations of image 1173 done!
# Fixations of image 1174 done!
# Fixations of image 1175 done!
# Fixations of image 1176 done!
# Fixations of image 1177 done!
# Fixations of image 1178 done!
# Fixations of image 1179 done!
# Fixations of image 1180 done!
# Fixations of image 1181 done!
# Fixations of image 1182 done!
# Fixations of image 1183 done!
# Fixations of image 1184 done!
# Fixations of image 1185 done!
# Fixations of image 1186 done!
# Fixations of image 1187 done!
# Fixations of image 1188 done!
# Fixations of image 1189 done!
# Fixations of image 1190 done!
# Fixations of image 1191 done!
# Fixations of image 1192 done!
# Fixations of image 1193 done!
# Fixations of image 1194 done!
# Fixations of image 1195 done!
# Fixations of image 1196 done!
# Fixations of image 1197 done!
# Fixations of image 1198 done!
# Fixations of image 1199 done!
# Fixations of image 1200 done!
# Fixations of image 1201 done!
# Fixations of image 1202 done!
# Fixations of image 1203 done!
# Fixations of image 1204 done!
# Fixations of image 1205 done!
# Fixations of image 1206 done!
# Fixations of image 1207 done!
# Fixations of image 1208 done!
# Fixations of image 1209 done!
# Fixations of image 1210 done!
# Fixations of image 1211 done!
# Fixations of image 1212 done!
# Fixations of image 1213 done!
# Fixations of image 1214 done!
# Fixations of image 1215 done!
# Fixations of image 1216 done!
# Fixations of image 1217 done!
# Fixations of image 1218 done!
# Fixations of image 1219 done!
# Fixations of image 1220 done!
# Fixations of image 1221 done!
# Fixations of image 1222 done!
# Fixations of image 1223 done!
# Fixations of image 1224 done!
# Fixations of image 1225 done!
# Fixations of image 1226 done!
# Fixations of image 1227 done!
# Fixations of image 1228 done!
# Fixations of image 1229 done!
# Fixations of image 1230 done!
# Fixations of image 1231 done!
# Fixations of image 1232 done!
# Fixations of image 1233 done!
# Fixations of image 1234 done!
# Fixations of image 1235 done!
# Fixations of image 1236 done!
# Fixations of image 1237 done!
# Fixations of image 1238 done!
# Fixations of image 1239 done!
# Fixations of image 1240 done!
# Fixations of image 1241 done!
# Fixations of image 1242 done!
# Fixations of image 1243 done!
# Fixations of image 1244 done!
# Fixations of image 1245 done!
# Fixations of image 1246 done!
# Fixations of image 1247 done!
# Fixations of image 1248 done!
# Fixations of image 1249 done!
# Fixations of image 1250 done!
# Fixations of image 1251 done!
# Fixations of image 1252 done!
# Fixations of image 1253 done!
# Fixations of image 1254 done!
# Fixations of image 1255 done!
# Fixations of image 1256 done!
# Fixations of image 1257 done!
# Fixations of image 1258 done!
# Fixations of image 1259 done!
# Fixations of image 1260 done!
# Fixations of image 1261 done!
# Fixations of image 1262 done!
# Fixations of image 1263 done!
# Fixations of image 1264 done!
# Fixations of image 1265 done!
# Fixations of image 1266 done!
# Fixations of image 1267 done!
# Fixations of image 1268 done!
# Fixations of image 1269 done!
# Fixations of image 1270 done!
# Fixations of image 1271 done!
# Fixations of image 1272 done!
# Fixations of image 1273 done!
# Fixations of image 1274 done!
# Fixations of image 1275 done!
# Fixations of image 1276 done!
# Fixations of image 1277 done!
# Fixations of image 1278 done!
# Fixations of image 1279 done!
# Fixations of image 1280 done!
# Fixations of image 1281 done!
# Fixations of image 1282 done!
# Fixations of image 1283 done!
# Fixations of image 1284 done!
# Fixations of image 1285 done!
# Fixations of image 1286 done!
# Fixations of image 1287 done!
# Fixations of image 1288 done!
# Fixations of image 1289 done!
# Fixations of image 1290 done!
# Fixations of image 1291 done!
# Fixations of image 1292 done!
# Fixations of image 1293 done!
# Fixations of image 1294 done!
# Fixations of image 1295 done!
# Fixations of image 1296 done!
# Fixations of image 1297 done!
# Fixations of image 1298 done!
# Fixations of image 1299 done!
# Fixations of image 1300 done!
# Fixations of image 1301 done!
# Fixations of image 1302 done!
# Fixations of image 1303 done!
# Fixations of image 1304 done!
# Fixations of image 1305 done!
# Fixations of image 1306 done!
# Fixations of image 1307 done!
# Fixations of image 1308 done!
# Fixations of image 1309 done!
# Fixations of image 1310 done!
# Fixations of image 1311 done!
# Fixations of image 1312 done!
# Fixations of image 1313 done!
# Fixations of image 1314 done!
# Fixations of image 1315 done!
# Fixations of image 1316 done!
# Fixations of image 1317 done!
# Fixations of image 1318 done!
# Fixations of image 1319 done!
# Fixations of image 1320 done!
# Fixations of image 1321 done!
# Fixations of image 1322 done!
# Fixations of image 1323 done!
# Fixations of image 1324 done!
# Fixations of image 1325 done!
# Fixations of image 1326 done!
# Fixations of image 1327 done!
# Fixations of image 1328 done!
# Fixations of image 1329 done!
# Fixations of image 1330 done!
# Fixations of image 1331 done!
# Fixations of image 1332 done!
# Fixations of image 1333 done!
# Fixations of image 1334 done!
# Fixations of image 1335 done!
# Fixations of image 1336 done!
# Fixations of image 1337 done!
# Fixations of image 1338 done!
# Fixations of image 1339 done!
# Fixations of image 1340 done!
# Fixations of image 1341 done!
# Fixations of image 1342 done!
# Fixations of image 1343 done!
# Fixations of image 1344 done!
# Fixations of image 1345 done!
# Fixations of image 1346 done!
# Fixations of image 1347 done!
# Fixations of image 1348 done!
# Fixations of image 1349 done!
# Fixations of image 1350 done!
# Fixations of image 1351 done!
# Fixations of image 1352 done!
# Fixations of image 1353 done!
# Fixations of image 1354 done!
# Fixations of image 1355 done!
# Fixations of image 1356 done!
# Fixations of image 1357 done!
# Fixations of image 1358 done!
# Fixations of image 1359 done!
# Fixations of image 1360 done!
# Fixations of image 1361 done!
# Fixations of image 1362 done!
# Fixations of image 1363 done!
# Fixations of image 1364 done!
# Fixations of image 1365 done!
# Fixations of image 1366 done!
# Fixations of image 1367 done!
# Fixations of image 1368 done!
# Fixations of image 1369 done!
# Fixations of image 1370 done!
# Fixations of image 1371 done!
# Fixations of image 1372 done!
# Fixations of image 1373 done!
# Fixations of image 1374 done!
# Fixations of image 1375 done!
# Fixations of image 1376 done!
# Fixations of image 1377 done!
# Fixations of image 1378 done!
# Fixations of image 1379 done!
# Fixations of image 1380 done!
# Fixations of image 1381 done!
# Fixations of image 1382 done!
# Fixations of image 1383 done!
# Fixations of image 1384 done!
# Fixations of image 1385 done!
# Fixations of image 1386 done!
# Fixations of image 1387 done!
# Fixations of image 1388 done!
# Fixations of image 1389 done!
# Fixations of image 1390 done!
# Fixations of image 1391 done!
# Fixations of image 1392 done!
# Fixations of image 1393 done!
# Fixations of image 1394 done!
# Fixations of image 1395 done!
# Fixations of image 1396 done!
# Fixations of image 1397 done!
# Fixations of image 1398 done!
# Fixations of image 1399 done!
# Fixations of image 1400 done!
# Fixations of image 1401 done!
# Fixations of image 1402 done!
# Fixations of image 1403 done!
# Fixations of image 1404 done!
# Fixations of image 1405 done!
# Fixations of image 1406 done!
# Fixations of image 1407 done!
# Fixations of image 1408 done!
# Fixations of image 1409 done!
# Fixations of image 1410 done!
# Fixations of image 1411 done!
# Fixations of image 1412 done!
# Fixations of image 1413 done!
# Fixations of image 1414 done!
# Fixations of image 1415 done!
# Fixations of image 1416 done!
# Fixations of image 1417 done!
# Fixations of image 1418 done!
# Fixations of image 1419 done!
# Fixations of image 1420 done!
# Fixations of image 1421 done!
# Fixations of image 1422 done!
# Fixations of image 1423 done!
# Fixations of image 1424 done!
# Fixations of image 1425 done!
# Fixations of image 1426 done!
# Fixations of image 1427 done!
# Fixations of image 1428 done!
# Fixations of image 1429 done!
# Fixations of image 1430 done!
# Fixations of image 1431 done!
# Fixations of image 1432 done!
# Fixations of image 1433 done!
# Fixations of image 1434 done!
# Fixations of image 1435 done!
# Fixations of image 1436 done!
# Fixations of image 1437 done!
# Fixations of image 1438 done!
# Fixations of image 1439 done!
# Fixations of image 1440 done!
# Fixations of image 1441 done!
# Fixations of image 1442 done!
# Fixations of image 1443 done!
# Fixations of image 1444 done!
# Fixations of image 1445 done!
# Fixations of image 1446 done!
# Fixations of image 1447 done!
# Fixations of image 1448 done!
# Fixations of image 1449 done!
# Fixations of image 1450 done!
# Fixations of image 1451 done!
# Fixations of image 1452 done!
# Fixations of image 1453 done!
# Fixations of image 1454 done!
# Fixations of image 1455 done!
# Fixations of image 1456 done!
# Fixations of image 1457 done!
# Fixations of image 1458 done!
# Fixations of image 1459 done!
# Fixations of image 1460 done!
# Fixations of image 1461 done!
# Fixations of image 1462 done!
# Fixations of image 1463 done!
# Fixations of image 1464 done!
# Fixations of image 1465 done!
# Fixations of image 1466 done!
# Fixations of image 1467 done!
# Fixations of image 1468 done!
# Fixations of image 1469 done!
# Fixations of image 1470 done!
# Fixations of image 1471 done!
# Fixations of image 1472 done!
# Fixations of image 1473 done!
# Fixations of image 1474 done!
# Fixations of image 1475 done!
# Fixations of image 1476 done!
# Fixations of image 1477 done!
# Fixations of image 1478 done!
# Fixations of image 1479 done!
# Fixations of image 1480 done!
# Fixations of image 1481 done!
# Fixations of image 1482 done!
# Fixations of image 1483 done!
# Fixations of image 1484 done!
# Fixations of image 1485 done!
# Fixations of image 1486 done!
# Fixations of image 1487 done!
# Fixations of image 1488 done!
# Fixations of image 1489 done!
# Fixations of image 1490 done!
# Fixations of image 1491 done!
# Fixations of image 1492 done!
# Fixations of image 1493 done!
# Fixations of image 1494 done!
# Fixations of image 1495 done!
# Fixations of image 1496 done!
# Fixations of image 1497 done!
# Fixations of image 1498 done!
# Fixations of image 1499 done!
# Fixations of image 1500 done!
# Fixations of image 1501 done!
# Fixations of image 1502 done!
# Fixations of image 1503 done!
# Fixations of image 1504 done!
# Fixations of image 1505 done!
# Fixations of image 1506 done!
# Fixations of image 1507 done!
# Fixations of image 1508 done!
# Fixations of image 1509 done!
# Fixations of image 1510 done!
# Fixations of image 1511 done!
# Fixations of image 1512 done!
# Fixations of image 1513 done!
# Fixations of image 1514 done!
# Fixations of image 1515 done!
# Fixations of image 1516 done!
# Fixations of image 1517 done!
# Fixations of image 1518 done!
# Fixations of image 1519 done!
# Fixations of image 1520 done!
# Fixations of image 1521 done!
# Fixations of image 1522 done!
# Fixations of image 1523 done!
# Fixations of image 1524 done!
# Fixations of image 1525 done!
# Fixations of image 1526 done!
# Fixations of image 1527 done!
# Fixations of image 1528 done!
# Fixations of image 1529 done!
# Fixations of image 1530 done!
# Fixations of image 1531 done!
# Fixations of image 1532 done!
# Fixations of image 1533 done!
# Fixations of image 1534 done!
# Fixations of image 1535 done!
# Fixations of image 1536 done!
# Fixations of image 1537 done!
# Fixations of image 1538 done!
# Fixations of image 1539 done!
# Fixations of image 1540 done!
# Fixations of image 1541 done!
# Fixations of image 1542 done!
# Fixations of image 1543 done!
# Fixations of image 1544 done!
# Fixations of image 1545 done!
# Fixations of image 1546 done!
# Fixations of image 1547 done!
# Fixations of image 1548 done!
# Fixations of image 1549 done!
# Fixations of image 1550 done!
# Fixations of image 1551 done!
# Fixations of image 1552 done!
# Fixations of image 1553 done!
# Fixations of image 1554 done!
# Fixations of image 1555 done!
# Fixations of image 1556 done!
# Fixations of image 1557 done!
# Fixations of image 1558 done!
# Fixations of image 1559 done!
# Fixations of image 1560 done!
# Fixations of image 1561 done!
# Fixations of image 1562 done!
# Fixations of image 1563 done!
# Fixations of image 1564 done!
# Fixations of image 1565 done!
# Fixations of image 1566 done!
# Fixations of image 1567 done!
# Fixations of image 1568 done!
# Fixations of image 1569 done!
# Fixations of image 1570 done!
# Fixations of image 1571 done!
# Fixations of image 1572 done!
# Fixations of image 1573 done!
# Fixations of image 1574 done!
# Fixations of image 1575 done!
# Fixations of image 1576 done!
# Fixations of image 1577 done!
# Fixations of image 1578 done!
# Fixations of image 1579 done!
# Fixations of image 1580 done!
# Fixations of image 1581 done!
# Fixations of image 1582 done!
# Fixations of image 1583 done!
# Fixations of image 1584 done!
# Fixations of image 1585 done!
# Fixations of image 1586 done!
# Fixations of image 1587 done!
# Fixations of image 1588 done!
# Fixations of image 1589 done!
# Fixations of image 1590 done!
# Fixations of image 1591 done!
# Fixations of image 1592 done!
# Fixations of image 1593 done!
# Fixations of image 1594 done!
# Fixations of image 1595 done!
# Fixations of image 1596 done!
# Fixations of image 1597 done!
# Fixations of image 1598 done!
# Fixations of image 1599 done!
# Fixations of image 1600 done!
# Fixations of image 1601 done!
# Fixations of image 1602 done!
# Fixations of image 1603 done!
# Fixations of image 1604 done!
# Fixations of image 1605 done!
# Fixations of image 1606 done!
# Fixations of image 1607 done!
# Fixations of image 1608 done!
# Fixations of image 1609 done!
# Fixations of image 1610 done!
# Fixations of image 1611 done!
# Fixations of image 1612 done!
# Fixations of image 1613 done!
# Fixations of image 1614 done!
# Fixations of image 1615 done!
# Fixations of image 1616 done!
# Fixations of image 1617 done!
# Fixations of image 1618 done!
# Fixations of image 1619 done!
# Fixations of image 1620 done!
# Fixations of image 1621 done!
# Fixations of image 1622 done!
# Fixations of image 1623 done!
# Fixations of image 1624 done!
# Fixations of image 1625 done!
# Fixations of image 1626 done!
# Fixations of image 1627 done!
# Fixations of image 1628 done!
# Fixations of image 1629 done!
# Fixations of image 1630 done!
# Fixations of image 1631 done!
# Fixations of image 1632 done!
# Fixations of image 1633 done!
# Fixations of image 1634 done!
# Fixations of image 1635 done!
# Fixations of image 1636 done!
# ...
# Fixations of image 3201 done!
# Fixations of image 3202 done!
# Fixations of image 3203 done!
# Fixations of image 3204 done!
# Fixations of image 3205 done!
# Fixations of image 3206 done!
# Fixations of image 3207 done!
# Fixations of image 3208 done!
# Fixations of image 3209 done!
# Fixations of image 3210 done!
# Fixations of image 3211 done!
# Fixations of image 3212 done!
# Fixations of image 3213 done!
# Fixations of image 3214 done!
# Fixations of image 3215 done!
# Fixations of image 3216 done!
# Fixations of image 3217 done!
# Fixations of image 3218 done!
# Fixations of image 3219 done!
# Fixations of image 3220 done!
# Fixations of image 3221 done!
# Fixations of image 3222 done!
# Fixations of image 3223 done!
# Fixations of image 3224 done!
# Fixations of image 3225 done!
# Fixations of image 3226 done!
# Fixations of image 3227 done!
# Fixations of image 3228 done!
# Fixations of image 3229 done!
# Fixations of image 3230 done!
# Fixations of image 3231 done!
# Fixations of image 3232 done!
# Fixations of image 3233 done!
# Fixations of image 3234 done!
# Fixations of image 3235 done!
# Fixations of image 3236 done!
# Fixations of image 3237 done!
# Fixations of image 3238 done!
# Fixations of image 3239 done!
# Fixations of image 3240 done!
# Fixations of image 3241 done!
# Fixations of image 3242 done!
# Fixations of image 3243 done!
# Fixations of image 3244 done!
# Fixations of image 3245 done!
# Fixations of image 3246 done!
# Fixations of image 3247 done!
# Fixations of image 3248 done!
# Fixations of image 3249 done!
# Fixations of image 3250 done!
# Fixations of image 3251 done!
# Fixations of image 3252 done!
# Fixations of image 3253 done!
# Fixations of image 3254 done!
# Fixations of image 3255 done!
# Fixations of image 3256 done!
# Fixations of image 3257 done!
# Fixations of image 3258 done!
# Fixations of image 3259 done!
# Fixations of image 3260 done!
# Fixations of image 3261 done!
# Fixations of image 3262 done!
# Fixations of image 3263 done!
# Fixations of image 3264 done!
# Fixations of image 3265 done!
# Fixations of image 3266 done!
# Fixations of image 3267 done!
# Fixations of image 3268 done!
# Fixations of image 3269 done!
# Fixations of image 3270 done!
# Fixations of image 3271 done!
# Fixations of image 3272 done!
# Fixations of image 3273 done!
# Fixations of image 3274 done!
# Fixations of image 3275 done!
# Fixations of image 3276 done!
# Fixations of image 3277 done!
# Fixations of image 3278 done!
# Fixations of image 3279 done!
# Fixations of image 3280 done!
# Fixations of image 3281 done!
# Fixations of image 3282 done!
# Fixations of image 3283 done!
# Fixations of image 3284 done!
# Fixations of image 3285 done!
# Fixations of image 3286 done!
# Fixations of image 3287 done!
# Fixations of image 3288 done!
# Fixations of image 3289 done!
# Fixations of image 3290 done!
# Fixations of image 3291 done!
# Fixations of image 3292 done!
# Fixations of image 3293 done!
# Fixations of image 3294 done!
# Fixations of image 3295 done!
# Fixations of image 3296 done!
# Fixations of image 3297 done!
# Fixations of image 3298 done!
# Fixations of image 3299 done!
# Fixations of image 3300 done!
# Fixations of image 3301 done!
# Fixations of image 3302 done!
# Fixations of image 3303 done!
# Fixations of image 3304 done!
# Fixations of image 3305 done!
# Fixations of image 3306 done!
# Fixations of image 3307 done!
# Fixations of image 3308 done!
# Fixations of image 3309 done!
# Fixations of image 3310 done!
# Fixations of image 3311 done!
# Fixations of image 3312 done!
# Fixations of image 3313 done!
# Fixations of image 3314 done!
# Fixations of image 3315 done!
# Fixations of image 3316 done!
# Fixations of image 3317 done!
# Fixations of image 3318 done!
# Fixations of image 3319 done!
# Fixations of image 3320 done!
# Fixations of image 3321 done!
# Fixations of image 3322 done!
# Fixations of image 3323 done!
# Fixations of image 3324 done!
# Fixations of image 3325 done!
# Fixations of image 3326 done!
# Fixations of image 3327 done!
# Fixations of image 3328 done!
# Fixations of image 3329 done!
# Fixations of image 3330 done!
# Fixations of image 3331 done!
# Fixations of image 3332 done!
# Fixations of image 3333 done!
# Fixations of image 3334 done!
# Fixations of image 3335 done!
# Fixations of image 3336 done!
# Fixations of image 3337 done!
# Fixations of image 3338 done!
# Fixations of image 3339 done!
# Fixations of image 3340 done!
# Fixations of image 3341 done!
# Fixations of image 3342 done!
# Fixations of image 3343 done!
# Fixations of image 3344 done!
# Fixations of image 3345 done!
# Fixations of image 3346 done!
# Fixations of image 3347 done!
# Fixations of image 3348 done!
# Fixations of image 3349 done!
# Fixations of image 3350 done!
# Fixations of image 3351 done!
# Fixations of image 3352 done!
# Fixations of image 3353 done!
# Fixations of image 3354 done!
# Fixations of image 3355 done!
# Fixations of image 3356 done!
# Fixations of image 3357 done!
# Fixations of image 3358 done!
# Fixations of image 3359 done!
# Fixations of image 3360 done!
# Fixations of image 3361 done!
# Fixations of image 3362 done!
# Fixations of image 3363 done!
# Fixations of image 3364 done!
# Fixations of image 3365 done!
# Fixations of image 3366 done!
# Fixations of image 3367 done!
# Fixations of image 3368 done!
# Fixations of image 3369 done!
# Fixations of image 3370 done!
# Fixations of image 3371 done!
# Fixations of image 3372 done!
# Fixations of image 3373 done!
# Fixations of image 3374 done!
# Fixations of image 3375 done!
# Fixations of image 3376 done!
# Fixations of image 3377 done!
# Fixations of image 3378 done!
# Fixations of image 3379 done!
# Fixations of image 3380 done!
# Fixations of image 3381 done!
# Fixations of image 3382 done!
# Fixations of image 3383 done!
# Fixations of image 3384 done!
# Fixations of image 3385 done!
# Fixations of image 3386 done!
# Fixations of image 3387 done!
# Fixations of image 3388 done!
# Fixations of image 3389 done!
# Fixations of image 3390 done!
# Fixations of image 3391 done!
# Fixations of image 3392 done!
# Fixations of image 3393 done!
# Fixations of image 3394 done!
# Fixations of image 3395 done!
# Fixations of image 3396 done!
# Fixations of image 3397 done!
# Fixations of image 3398 done!
# Fixations of image 3399 done!
# Fixations of image 3400 done!
# Fixations of image 3401 done!
# Fixations of image 3402 done!
# Fixations of image 3403 done!
# Fixations of image 3404 done!
# Fixations of image 3405 done!
# Fixations of image 3406 done!
# Fixations of image 3407 done!
# Fixations of image 3408 done!
# Fixations of image 3409 done!
# Fixations of image 3410 done!
# Fixations of image 3411 done!
# Fixations of image 3412 done!
# Fixations of image 3413 done!
# Fixations of image 3414 done!
# Fixations of image 3415 done!
# Fixations of image 3416 done!
# Fixations of image 3417 done!
# Fixations of image 3418 done!
# Fixations of image 3419 done!
# Fixations of image 3420 done!
# Fixations of image 3421 done!
# Fixations of image 3422 done!
# Fixations of image 3423 done!
# Fixations of image 3424 done!
# Fixations of image 3425 done!
# Fixations of image 3426 done!
# Fixations of image 3427 done!
# Fixations of image 3428 done!
# Fixations of image 3429 done!
# Fixations of image 3430 done!
# Fixations of image 3431 done!
# Fixations of image 3432 done!
# Fixations of image 3433 done!
# Fixations of image 3434 done!
# Fixations of image 3435 done!
# Fixations of image 3436 done!
# Fixations of image 3437 done!
# Fixations of image 3438 done!
# Fixations of image 3439 done!
# Fixations of image 3440 done!
# Fixations of image 3441 done!
# Fixations of image 3442 done!
# Fixations of image 3443 done!
# Fixations of image 3444 done!
# Fixations of image 3445 done!
# Fixations of image 3446 done!
# Fixations of image 3447 done!
# Fixations of image 3448 done!
# Fixations of image 3449 done!
# Fixations of image 3450 done!
# Fixations of image 3451 done!
# Fixations of image 3452 done!
# Fixations of image 3453 done!
# Fixations of image 3454 done!
# Fixations of image 3455 done!
# Fixations of image 3456 done!
# Fixations of image 3457 done!
# Fixations of image 3458 done!
# Fixations of image 3459 done!
# Fixations of image 3460 done!
# Fixations of image 3461 done!
# Fixations of image 3462 done!
# Fixations of image 3463 done!
# Fixations of image 3464 done!
# Fixations of image 3465 done!
# Fixations of image 3466 done!
# Fixations of image 3467 done!
# Fixations of image 3468 done!
# Fixations of image 3469 done!
# Fixations of image 3470 done!
# Fixations of image 3471 done!
# Fixations of image 3472 done!
# Fixations of image 3473 done!
# Fixations of image 3474 done!
# Fixations of image 3475 done!
# Fixations of image 3476 done!
# Fixations of image 3477 done!
# Fixations of image 3478 done!
# Fixations of image 3479 done!
# Fixations of image 3480 done!
# Fixations of image 3481 done!
# Fixations of image 3482 done!
# Fixations of image 3483 done!
# Fixations of image 3484 done!
# Fixations of image 3485 done!
# Fixations of image 3486 done!
# Fixations of image 3487 done!
# Fixations of image 3488 done!
# Fixations of image 3489 done!
# Fixations of image 3490 done!
# Fixations of image 3491 done!
# Fixations of image 3492 done!
# Fixations of image 3493 done!
# Fixations of image 3494 done!
# Fixations of image 3495 done!
# Fixations of image 3496 done!
# Fixations of image 3497 done!
# Fixations of image 3498 done!
# Fixations of image 3499 done!
# Fixations of image 3500 done!
# Fixations of image 3501 done!
# Fixations of image 3502 done!
# Fixations of image 3503 done!
# Fixations of image 3504 done!
# Fixations of image 3505 done!
# Fixations of image 3506 done!
# Fixations of image 3507 done!
# Fixations of image 3508 done!
# Fixations of image 3509 done!
# Fixations of image 3510 done!
# Fixations of image 3511 done!
# Fixations of image 3512 done!
# Fixations of image 3513 done!
# Fixations of image 3514 done!
# Fixations of image 3515 done!
# Fixations of image 3516 done!
# Fixations of image 3517 done!
# Fixations of image 3518 done!
# Fixations of image 3519 done!
# Fixations of image 3520 done!
# Fixations of image 3521 done!
# Fixations of image 3522 done!
# Fixations of image 3523 done!
# Fixations of image 3524 done!
# Fixations of image 3525 done!
# Fixations of image 3526 done!
# Fixations of image 3527 done!
# Fixations of image 3528 done!
# Fixations of image 3529 done!
# Fixations of image 3530 done!
# Fixations of image 3531 done!
# Fixations of image 3532 done!
# Fixations of image 3533 done!
# Fixations of image 3534 done!
# Fixations of image 3535 done!
# Fixations of image 3536 done!
# Fixations of image 3537 done!
# Fixations of image 3538 done!
# Fixations of image 3539 done!
# Fixations of image 3540 done!
# Fixations of image 3541 done!
# Fixations of image 3542 done!
# Fixations of image 3543 done!
# Fixations of image 3544 done!
# Fixations of image 3545 done!
# Fixations of image 3546 done!
# Fixations of image 3547 done!
# Fixations of image 3548 done!
# Fixations of image 3549 done!
# Fixations of image 3550 done!
# Fixations of image 3551 done!
# Fixations of image 3552 done!
# Fixations of image 3553 done!
# Fixations of image 3554 done!
# Fixations of image 3555 done!
# Fixations of image 3556 done!
# Fixations of image 3557 done!
# Fixations of image 3558 done!
# Fixations of image 3559 done!
# Fixations of image 3560 done!
# Fixations of image 3561 done!
# Fixations of image 3562 done!
# Fixations of image 3563 done!
# Fixations of image 3564 done!
# Fixations of image 3565 done!
# Fixations of image 3566 done!
# Fixations of image 3567 done!
# Fixations of image 3568 done!
# Fixations of image 3569 done!
# Fixations of image 3570 done!
# Fixations of image 3571 done!
# Fixations of image 3572 done!
# Fixations of image 3573 done!
# Fixations of image 3574 done!
# Fixations of image 3575 done!
# Fixations of image 3576 done!
# Fixations of image 3577 done!
# Fixations of image 3578 done!
# Fixations of image 3579 done!
# Fixations of image 3580 done!
# Fixations of image 3581 done!
# Fixations of image 3582 done!
# Fixations of image 3583 done!
# Fixations of image 3584 done!
# Fixations of image 3585 done!
# Fixations of image 3586 done!
# Fixations of image 3587 done!
# Fixations of image 3588 done!
# Fixations of image 3589 done!
# Fixations of image 3590 done!
# Fixations of image 3591 done!
# Fixations of image 3592 done!
# Fixations of image 3593 done!
# Fixations of image 3594 done!
# Fixations of image 3595 done!
# Fixations of image 3596 done!
# Fixations of image 3597 done!
# Fixations of image 3598 done!
# Fixations of image 3599 done!
# Fixations of image 3600 done!
# Fixations of image 3601 done!
# Fixations of image 3602 done!
# Fixations of image 3603 done!
# Fixations of image 3604 done!
# Fixations of image 3605 done!
# Fixations of image 3606 done!
# Fixations of image 3607 done!
# Fixations of image 3608 done!
# Fixations of image 3609 done!
# Fixations of image 3610 done!
# Fixations of image 3611 done!
# Fixations of image 3612 done!
# Fixations of image 3613 done!
# Fixations of image 3614 done!
# Fixations of image 3615 done!
# Fixations of image 3616 done!
# Fixations of image 3617 done!
# Fixations of image 3618 done!
# Fixations of image 3619 done!
# Fixations of image 3620 done!
# Fixations of image 3621 done!
# Fixations of image 3622 done!
# Fixations of image 3623 done!
# Fixations of image 3624 done!
# Fixations of image 3625 done!
# Fixations of image 3626 done!
# Fixations of image 3627 done!
# Fixations of image 3628 done!
# Fixations of image 3629 done!
# Fixations of image 3630 done!
# Fixations of image 3631 done!
# Fixations of image 3632 done!
# Fixations of image 3633 done!
# Fixations of image 3634 done!
# Fixations of image 3635 done!
# Fixations of image 3636 done!
# Fixations of image 3637 done!
# Fixations of image 3638 done!
# Fixations of image 3639 done!
# Fixations of image 3640 done!
# Fixations of image 3641 done!
# Fixations of image 3642 done!
# Fixations of image 3643 done!
# Fixations of image 3644 done!
# Fixations of image 3645 done!
# Fixations of image 3646 done!
# Fixations of image 3647 done!
# Fixations of image 3648 done!
# Fixations of image 3649 done!
# Fixations of image 3650 done!
# Fixations of image 3651 done!
# Fixations of image 3652 done!
# Fixations of image 3653 done!
# Fixations of image 3654 done!
# Fixations of image 3655 done!
# Fixations of image 3656 done!
# Fixations of image 3657 done!
# Fixations of image 3658 done!
# Fixations of image 3659 done!
# Fixations of image 3660 done!
# Fixations of image 3661 done!
# Fixations of image 3662 done!
# Fixations of image 3663 done!
# Fixations of image 3664 done!
# Fixations of image 3665 done!
# Fixations of image 3666 done!
# Fixations of image 3667 done!
# Fixations of image 3668 done!
# Fixations of image 3669 done!
# Fixations of image 3670 done!
# Fixations of image 3671 done!
# Fixations of image 3672 done!
# Fixations of image 3673 done!
# Fixations of image 3674 done!
# Fixations of image 3675 done!
# Fixations of image 3676 done!
# Fixations of image 3677 done!
# Fixations of image 3678 done!
# Fixations of image 3679 done!
# Fixations of image 3680 done!
# Fixations of image 3681 done!
# Fixations of image 3682 done!
# Fixations of image 3683 done!
# Fixations of image 3684 done!
# Fixations of image 3685 done!
# Fixations of image 3686 done!
# Fixations of image 3687 done!
# Fixations of image 3688 done!
# Fixations of image 3689 done!
# Fixations of image 3690 done!
# Fixations of image 3691 done!
# Fixations of image 3692 done!
# Fixations of image 3693 done!
# Fixations of image 3694 done!
# Fixations of image 3695 done!
# Fixations of image 3696 done!
# Fixations of image 3697 done!
# Fixations of image 3698 done!
# Fixations of image 3699 done!
# Fixations of image 3700 done!
# Fixations of image 3701 done!
# Fixations of image 3702 done!
# Fixations of image 3703 done!
# Fixations of image 3704 done!
# Fixations of image 3705 done!
# Fixations of image 3706 done!
# Fixations of image 3707 done!
# Fixations of image 3708 done!
# Fixations of image 3709 done!
# Fixations of image 3710 done!
# Fixations of image 3711 done!
# Fixations of image 3712 done!
# Fixations of image 3713 done!
# Fixations of image 3714 done!
# Fixations of image 3715 done!
# Fixations of image 3716 done!
# Fixations of image 3717 done!
# Fixations of image 3718 done!
# Fixations of image 3719 done!
# Fixations of image 3720 done!
# Fixations of image 3721 done!
# Fixations of image 3722 done!
# Fixations of image 3723 done!
# Fixations of image 3724 done!
# Fixations of image 3725 done!
# Fixations of image 3726 done!
# Fixations of image 3727 done!
# Fixations of image 3728 done!
# Fixations of image 3729 done!
# Fixations of image 3730 done!
# Fixations of image 3731 done!
# Fixations of image 3732 done!
# Fixations of image 3733 done!
